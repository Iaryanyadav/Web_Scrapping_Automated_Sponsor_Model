# %% [markdown]
# # Web Scrapping

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_website_data(url):
    HEADERS = {}
    response = requests.get(url, headers=HEADERS)
    soup = BeautifulSoup(response.content, 'html.parser')

    # ---------- EVENTS SECTION ----------
    events_section = soup.find("section", class_="events")
    events_data = []

    if events_section:
        cards = events_section.find_all("div", class_="card")
        for card in cards:
            brand = card.find("h3")
            desc = card.find("p")

            events_data.append({
                "brand": brand.get_text(strip=True) if brand else None,
                "description": desc.get_text(strip=True) if desc else None
            })

    # Save to CSV
    df = pd.DataFrame(events_data)
    df.to_csv("website_data.csv", index=False, encoding='utf-8')
    print(" Data saved to 'website_data.csv' successfully!")

    return events_data


# Run the scraper
url = 'https://iaryanyadav.github.io/project_1/'
final_data = scrape_website_data(url)

# Optional: print preview
print(final_data)
# Out:
#  Data saved to 'website_data.csv' successfully!
# [{'brand': 'CocaCola', 'description': 'During the Fashion Week, CocaCola sponsored exclusive discounts on Refrigerator. Customers rushed to grab the best deals from CocaCola as part of this e-commerce event.'}, {'brand': 'Samsung', 'description': 'During the Tech Summit, Samsung sponsored exclusive discounts on Smart Watch. Customers rushed to grab the best deals from Samsung as part of this e-commerce event.'}, {'brand': 'Nike', 'description': 'During the Summer Sale, Nike sponsored exclusive discounts on Running Shoes. Customers rushed to grab the best deals from Nike as part of this e-commerce event.'}, {'brand': 'Microsoft', 'description': 'During the Cyber Monday, Microsoft sponsored exclusive discounts on Surface Laptop. Customers rushed to grab the best deals from Microsoft as part of this e-commerce event.'}, {'brand': 'Sony', 'description': 'During the New Year Sale, Sony sponsored exclusive discounts on Headphones. Customers rushed to grab the best deals from Sony as part of this e-commerce event.'}, {'brand': 'Love', 'description': 'They inspire to stay focused on my dearest dreams and help overcome all the challenges I face.'}, {'brand': 'Content', 'description': 'I know how hard it is to work as a content marketer as you must always be creative, ready to adjust to new challenges and learn fast.'}, {'brand': 'Benjamin Franklin', 'description': 'Either write sth worth reading or do sth worth writing about.'}]

# %% [markdown]
# #Model Training

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')   # Optional, improves lemmatization
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# ---------- Sponsor Model Training (Text Data) ----------
import pandas as pd
import numpy as np
import string
import joblib
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ----------------------------------------------
# 1️ Text Preprocessing Helpers
# ----------------------------------------------
lemmatizer = WordNetLemmatizer()

def lemmatize_word(word, lemmatizer):
    for pos in ['n', 'v', 'a', 'r', 's']:
        lemmatized_word = lemmatizer.lemmatize(word, pos)
        if lemmatized_word != word:
            return lemmatized_word
    return lemmatizer.lemmatize(word)

def normalize_text(tokens):
    """Lowercase, remove punctuation, and lemmatize tokens."""
    tokens = [word.lower() for word in tokens]
    tokens = [word for word in tokens if word not in string.punctuation]
    tokens = [lemmatize_word(word, lemmatizer) for word in tokens]
    return tokens

# ----------------------------------------------
# 2️ Load Your Dataset
# ----------------------------------------------
# CSV should have columns: brand_name, description, status
df = pd.read_csv('sponsor_detection.csv')
print(df['status'].value_counts())

# Check for missing values
df = df.dropna(subset=['description', 'status'])

# Tokenization and normalization
df['tokenized_text'] = df['description'].apply(word_tokenize)
df['tokenized_text'] = df['tokenized_text'].apply(normalize_text)
df['joined_text'] = df['tokenized_text'].apply(lambda tokens: ' '.join(tokens))

# ----------------------------------------------
# 3️ TF-IDF Feature Extraction
# ----------------------------------------------
tfidf_vectorizer = TfidfVectorizer(max_features=5000)
X_tfidf = tfidf_vectorizer.fit_transform(df['joined_text'])
y = df['status']   # Target variable (0 = Not Sponsored, 1 = Sponsored)

# ----------------------------------------------
# 4️ Split Data
# ----------------------------------------------
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

# ----------------------------------------------
# 5️ Train Logistic Regression Model
# ----------------------------------------------
sponsor_model = RandomForestClassifier(
    n_estimators=200,         # number of trees in the forest
    random_state=42,          # for reproducibility
    class_weight='balanced'   # handle class imbalance
)

sponsor_model.fit(X_train, y_train)

# ----------------------------------------------
# 6️ Evaluate Model
# ----------------------------------------------
y_pred = sponsor_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(" Sponsor Model Performance:")
print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")

# ----------------------------------------------
# 7️ Save Model & Vectorizer
# ----------------------------------------------
joblib.dump(sponsor_model, "sponsor_model.pkl")
joblib.dump(tfidf_vectorizer, "tfidf_vectorizer.pkl")

print("\n Model and vectorizer saved successfully!")
# Out:
# status
# sponsor        5008
# non-sponsor    4992
# Name: count, dtype: int64
#  Sponsor Model Performance:
# Accuracy : 1.0000
# Precision: 1.0000
# Recall   : 1.0000
# F1 Score : 1.0000
#
#  Model and vectorizer saved successfully!

# %% [markdown]
# #Prediction

# %%
# ---------- Sponsor Prediction ----------
import joblib

# Load saved model & vectorizer
sponsor_model = joblib.load("sponsor_model.pkl")
vectorizer = joblib.load("tfidf_vectorizer.pkl")

# Example DataFrame with text column
df = pd.DataFrame({
    'text': [
        "Powered by Intel — bringing innovation to every gamer.",
        "NASA launched a satellite to study climate impact."
    ]
})

# Transform text and predict
X_tfidf = vectorizer.transform(df['text'])
df['is_sponsor'] = sponsor_model.predict(X_tfidf)

print(df)
# Out:
#                                                 text   is_sponsor
# 0  Powered by Intel — bringing innovation to ever...      sponsor
# 1  NASA launched a satellite to study climate imp...  non-sponsor

# %% [markdown]
# #Restart

# %%
import pandas as pd
import datetime
import time
import requests
from bs4 import BeautifulSoup
import joblib
import re
from sklearn.feature_extraction.text import TfidfVectorizer

# ==============================================================
# 1️ Load model and vectorizer
# ==============================================================
model = joblib.load("sponsor_model.pkl")
vectorizer = joblib.load("tfidf_vectorizer.pkl")

# ==============================================================
# 2️ Brand keyword list
# ==============================================================
BRANDS = [
    "Apple", "Samsung", "Nike", "Adidas", "Sony",
    "Microsoft", "Toyota", "CocaCola", "Pepsi", "Amazon",
    "Google", "Tesla", "Intel", "Puma", "Oppo", "Vivo"
]

def extract_brand(text):
    for brand in BRANDS:
        if re.search(rf"\b{brand}\b", text, re.IGNORECASE):
            return brand
    return "Other"

# ==============================================================
# 3️ Scrape only relevant text
# ==============================================================
def scrape_website(url):
    try:
        response = requests.get(url, timeout=10)
        soup = BeautifulSoup(response.text, "html.parser")
        cards = soup.find_all("div", class_="card")
        paragraphs = [
            card.get_text(strip=True)
            for card in cards
            if card.find("p")
        ]
        filtered = [
            t for t in paragraphs
            if any(b.lower() in t.lower() for b in BRANDS)
            or "sponsor" in t.lower()
            or "brand" in t.lower()
        ]
        return filtered
    except Exception as e:
        print(f" Error scraping {url}: {e}")
        return []
# ==============================================================
# 4️ Predict sponsorship
# ==============================================================
def predict_sponsorship(texts):
    if not texts:
        return []
    X_new = vectorizer.transform(texts)
    return model.predict(X_new)

# ==============================================================
# 5️⃣ Load or create activity log
# ==============================================================
try:
    activity_log = pd.read_csv("website_activity_log.csv")
except FileNotFoundError:
    activity_log = pd.DataFrame(columns=[
        "brand", "description", "is_sponsored",
        "url", "active_since", "active_until"
    ])

# ==============================================================
# 6️⃣ Main tracking function
# ==============================================================
def track_website(url):
    global activity_log
    print(f"\n Checking: {url} at {datetime.datetime.now()}")

    # Step 1: Scrape + Predict
    current_texts = scrape_website(url)
    if not current_texts:
        print(" No relevant brand/sponsor content found.")
        return

    current_preds = predict_sponsorship(current_texts)
    current_df = pd.DataFrame({
        "brand": [extract_brand(t) for t in current_texts],
        "description": current_texts,
        "is_sponsored": current_preds,
        "url": [url] * len(current_texts)
    })

    # Step 2: Remove duplicates
    current_df.drop_duplicates(subset=["url", "description"], inplace=True)
    activity_log.drop_duplicates(subset=["url", "description", "active_since"], inplace=True)

    # Step 3: Determine active and inactive sets
    existing_entries = activity_log[activity_log["url"] == url]

    # texts that are currently active (not removed)
    active_old = set(existing_entries.loc[existing_entries["active_until"].isna(), "description"])
    old_texts_all = set(existing_entries["description"])
    new_texts = set(current_df["description"])

    # Added = new ones not in currently active set
    added = new_texts - active_old
    # Removed = currently active ones not seen now
    removed = active_old - new_texts

    # Step 4: Add new entries (always as new rows, even if reappeared)
    for text in added:
        brand = extract_brand(text)
        pred = model.predict(vectorizer.transform([text]))[0]
        entry = {
            "brand": brand,
            "description": text,
            "is_sponsored": pred,
            "url": url,
            "active_since": datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
            "active_until": None
        }
        activity_log = pd.concat([activity_log, pd.DataFrame([entry])], ignore_index=True)
        print(f"🆕 Added new text for {brand}: {text[:70]}...")

    # Step 5: Mark removed ones
    for text in removed:
        mask = (
            (activity_log["url"] == url)
            & (activity_log["description"] == text)
            & (activity_log["active_until"].isna())
        )
        if mask.any():
            activity_log.loc[mask, "active_until"] = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            print(f" Marked removed text: {text[:70]}...")

    # Step 6: Save clean CSV
    activity_log.to_csv("website_activity_log.csv", index=False)
    print(" Log updated and saved cleanly!")

# ==============================================================
# 7️ Continuous monitoring loop
# ==============================================================
urls_to_track = ["https://iaryanyadav.github.io/project_1/"]

while True:
    for url in urls_to_track:
        track_website(url)

    print("⏳ Sleeping for 10 seconds before next check...\n")
    time.sleep(10)
# Out:
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:28:20.310628
# 🆕 Added new text for Nike: ☀️ Summer SaleRunning ShoesNikeDuring the Summer Sale, Nike sponsored ...
# 🆕 Added new text for Microsoft: 💻 Cyber MondaySurface LaptopMicrosoftDuring the Cyber Monday, Microsof...
# 🆕 Added new text for CocaCola: 🎉 Fashion WeekRefrigeratorCocaColaDuring the Fashion Week, CocaCola sp...
# 🆕 Added new text for Sony: 🎆 New Year SaleHeadphonesSonyDuring the New Year Sale, Sony sponsored ...
# 🆕 Added new text for Samsung: 📱 Tech SummitSmart WatchSamsungDuring the Tech Summit, Samsung sponsor...
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:28:30.496029
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:28:40.534531
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:28:50.573056
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:29:00.623188
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:29:10.661916
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:29:20.698558
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:29:30.744409
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:29:40.784690
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:29:50.839593
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:30:00.884525
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:30:10.922378
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:30:20.962249
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:30:31.011411
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:30:41.052491
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:30:51.090324
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:31:01.137504
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:31:11.198051
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:31:21.235359
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:31:31.278363
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:31:41.315676
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:31:51.354405
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:32:01.400505
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:32:11.441234
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:32:21.495946
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:32:31.540707
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:32:41.579387
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:32:51.618530
# 🆕 Added new text for Adidas: 🌸 Spring FestivalSports GearAdidasDuring the Spring Festival, Adidas s...
#  Marked removed text: 🎆 New Year SaleHeadphonesSonyDuring the New Year Sale, Sony sponsored ...
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:33:01.688520
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:33:11.727891
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:33:21.769824
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:33:31.824370
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:33:41.879729
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:33:51.917032
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:34:01.976487
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:34:12.020298
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:34:22.059627
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:34:32.115562
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:34:42.164145
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:34:52.204987
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:35:02.250784
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:35:12.316062
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:35:22.355046
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:35:32.401643
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:35:42.444756
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:35:52.483229
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:36:02.546182
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:36:12.590241
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:36:22.630869
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:36:32.697982
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:36:42.742999
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:36:52.786145
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:37:03.171264
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:37:13.211358
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:37:23.254990
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:37:33.312964
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:37:43.352344
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:37:53.396706
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:38:03.477140
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:38:13.524923
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:38:23.566210
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:38:33.618228
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:38:43.661514
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:38:53.706302
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:39:03.742977
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:39:13.784308
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:39:23.863922
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:39:33.902190
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:39:43.945369
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:39:53.989232
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:40:04.035215
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:40:14.078766
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:40:24.118506
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:40:34.163699
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:40:44.210702
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:40:54.259520
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:41:04.304832
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:41:14.351382
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:41:24.392513
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:41:34.437515
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:41:44.481556
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:41:54.536793
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:42:04.586750
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:42:14.628599
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:42:24.685514
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:42:34.729566
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:42:44.773260
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:42:54.814166
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:43:04.853785
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:43:14.892660
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:43:24.937625
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:43:34.975465
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:43:45.032314
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:43:55.076683
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:44:05.126528
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:44:15.172912
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:44:25.216133
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:44:35.255972
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:44:45.294869
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:44:55.337986
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:45:05.380354
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:45:15.435062
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:45:25.478137
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:45:35.522516
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:45:45.569401
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:45:55.611492
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:46:05.650936
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:46:15.696912
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:46:25.747161
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:46:35.803864
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:46:45.852558
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:46:55.895810
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:47:05.935818
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:47:15.977961
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:47:26.016749
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:47:36.058788
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:47:46.104800
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:47:56.146301
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:48:06.199543
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:48:16.239449
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:48:26.283059
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:48:36.348161
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:48:46.392198
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:48:56.432721
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:49:06.478660
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:49:16.526878
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:49:26.581021
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:49:36.625429
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:49:46.665081
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:49:56.706807
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:50:06.751932
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:50:16.788859
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:50:26.832713
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:50:36.873382
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:50:46.914280
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:50:56.972289
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:51:07.011969
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:51:17.057771
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:51:27.102814
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:51:37.141873
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:51:47.179559
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:51:57.217618
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:52:07.259707
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:52:17.319538
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:52:27.359902
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:52:37.405796
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:52:47.447325
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:52:57.487896
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:53:07.532544
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:53:17.570626
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:53:27.616544
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:53:37.664545
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:53:47.721925
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:53:57.762506
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:54:07.807543
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:54:17.852244
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:54:27.901768
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:54:37.947838
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:54:47.988224
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:54:58.029243
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:55:08.073387
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:55:18.134286
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:55:28.175704
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:55:38.214142
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:55:48.262339
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:55:58.302986
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:56:08.345736
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:56:18.390758
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:56:28.430408
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:56:38.489802
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:56:48.531542
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:56:58.579101
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:57:08.622835
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:57:18.661141
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:57:28.701763
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:57:38.744194
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:57:48.790952
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:57:58.833990
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:58:08.895970
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:58:18.933733
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:58:28.972093
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:58:39.022508
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:58:49.061106
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:58:59.106639
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:59:09.160434
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:59:19.212279
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:59:29.272860
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:59:39.317917
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:59:49.354996
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 06:59:59.398674
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:00:09.436964
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:00:19.480770
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:00:29.526998
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:00:39.568626
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:00:49.608380
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:00:59.663185
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:01:09.703199
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:01:19.746396
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:01:29.785663
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:01:39.826901
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:01:49.871438
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:01:59.914859
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:02:09.953380
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:02:20.009056
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:02:30.047132
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:02:40.090038
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:02:50.133177
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:03:00.171795
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:03:10.219973
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:03:20.262046
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:03:30.300588
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:03:40.343251
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:03:50.400503
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:04:00.442733
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:04:10.486619
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:04:20.529219
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:04:30.569737
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:04:40.613338
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:04:50.658574
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:05:00.697725
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:05:10.763009
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:05:20.809960
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:05:30.848297
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:05:40.886514
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:05:50.928495
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:06:00.974497
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:06:11.013496
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:06:21.060326
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:06:31.104599
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:06:41.159099
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:06:51.197901
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:07:01.252850
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:07:11.294689
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:07:21.335126
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:07:31.381520
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:07:41.425421
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:07:51.461883
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:08:01.506910
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:08:11.566567
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:08:21.606010
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:08:31.643899
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:08:41.688282
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:08:51.731071
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:09:01.768488
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:09:11.825300
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:09:21.864663
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:09:31.916163
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:09:41.956276
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:09:52.002114
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:10:02.040051
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:10:12.082496
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:10:22.127882
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:10:32.168926
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:10:42.207903
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:10:52.253977
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:11:02.315951
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:11:12.356514
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:11:22.396413
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:11:32.441784
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:11:42.481117
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:11:52.524175
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:12:02.567577
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:12:12.613685
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:12:22.675211
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:12:32.710967
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:12:42.756385
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:12:52.797317
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:13:02.840619
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:13:12.886707
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:13:22.929947
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:13:32.971223
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:13:43.028597
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:13:53.085118
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:14:03.129307
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:14:13.168761
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:14:23.210518
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:14:33.252777
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:14:43.293663
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:14:53.335351
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:15:03.376226
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:15:13.434918
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:15:23.473657
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:15:33.517087
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:15:43.558414
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:15:53.598798
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:16:03.638878
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:16:13.676171
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:16:23.715900
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:16:33.757219
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:16:43.809120
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:16:53.853277
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:17:03.892667
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:17:13.941900
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:17:23.982249
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:17:34.042113
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:17:44.081890
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:17:54.125291
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:18:04.189859
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:18:14.237013
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:18:24.276221
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:18:34.335219
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:18:44.374827
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:18:54.416507
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:19:04.464345
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:19:14.541485
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:19:24.589417
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:19:34.642155
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:19:44.706500
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:19:54.822373
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:20:04.860240
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:20:14.899181
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:20:24.942733
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:20:34.995810
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:20:45.038789
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:20:55.077014
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:21:05.132588
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:21:15.176802
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:21:25.217526
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:21:35.265033
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:21:45.306839
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:21:55.346604
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:22:05.388483
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:22:15.430388
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:22:25.484501
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:22:35.528780
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:22:45.574913
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:22:55.616804
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:23:05.662712
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:23:15.701921
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:23:25.740166
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:23:35.783280
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:23:45.834927
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:23:55.890242
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:24:05.928918
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:24:15.972312
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:24:26.023229
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:24:36.062509
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:24:46.104249
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:24:56.147012
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:25:06.191809
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:25:16.256755
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:25:26.294788
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:25:36.333521
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:25:46.374513
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:25:56.420356
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:26:06.464794
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:26:16.513374
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:26:26.552387
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:26:36.597348
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:26:46.649433
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:26:56.691494
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:27:06.736678
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:27:16.776169
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:27:26.822612
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:27:36.862497
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:27:46.907085
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:27:56.952601
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:28:06.992405
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...
#
#
#  Checking: https://iaryanyadav.github.io/project_1/ at 2025-11-05 07:28:17.064255
#  Log updated and saved cleanly!
# ⏳ Sleeping for 10 seconds before next check...

# %% [markdown]
# #Extract text from image

# %%
import os

print("Model exists:", os.path.exists("sponsor_model.pkl"))
print("Vectorizer exists:", os.path.exists("tfidf_vectorizer.pkl"))

# %%
# !pip install easyocr

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin   # ✅ Needed for full image URLs
import pandas as pd                # ✅ Needed to save CSV

# Step 1: Enter your target webpage URL
url = "https://iaryanyadav.github.io/project_1/"   # 🔹 Replace this with your actual webpage

# Step 2: Get the HTML content of the page
response = requests.get(url)
response.raise_for_status()  # Optional: raises error if request fails

# Step 3: Parse HTML using BeautifulSoup
soup = BeautifulSoup(response.text, "html.parser")

# Step 4: Find all <img> tags
image_tags = soup.find_all("img")

# Step 5: Extract image URLs (handle both absolute & relative URLs)
image_links = []
for img in image_tags:
    src = img.get("src")
    if src:
        full_url = urljoin(url, src)
        image_links.append(full_url)

# Step 6: Save all image URLs to a CSV file
if image_links:
    df = pd.DataFrame({"image_url": image_links})
    df.to_csv("image_links.csv", index=False)
    print(f"✅ {len(image_links)} image links saved to image_links.csv")
else:
    print("⚠ No image URLs found on the page.")

# %%
import pandas as pd

# Replace 'your_csv_file.csv' with the actual path to your CSV file.
df = pd.read_csv('image_links.csv')

# Display the first few rows of the DataFrame
display(df.head())

# Display information about the DataFrame
display(df.info())

# %%
import easyocr
import requests
from PIL import Image
from io import BytesIO
import numpy as np
import pandas as pd

# Load your CSV file (if not already loaded)
df = pd.read_csv("image_links.csv")

# Initialize the EasyOCR reader
reader = easyocr.Reader(['en'])

# Create a new column for extracted text
df['extracted_text'] = None

# Loop through each image URL and extract text
for index, row in df.iterrows():
    url = row['image_url']   # ✅ corrected column name
    print(f"Processing image: {url}")
    try:
        if "wikimedia.org" in url:
            headers = {'User-Agent': 'Mozilla/5.0'}
            response = requests.get(url, headers=headers)
        else:
            response = requests.get(url)

        response.raise_for_status()

        try:
            result = reader.readtext(response.content)
        except Exception:
            img = Image.open(BytesIO(response.content))
            img_np = np.array(img)
            result = reader.readtext(img_np)

        # Store the extracted text
        if result:
            extracted_texts = [text for (bbox, text, prob) in result]
            df.at[index, 'extracted_text'] = ", ".join(extracted_texts)
            print(f"  Extracted Text: {', '.join(extracted_texts)}")
        else:
            df.at[index, 'extracted_text'] = "No text found"
            print("  No text found in this image.")

    except requests.exceptions.RequestException as e:
        df.at[index, 'extracted_text'] = f"Error fetching image: {e}"
        print(f"  Error fetching image: {e}")
    except Exception as e:
        df.at[index, 'extracted_text'] = f"Error processing image: {e}"
        print(f"  Error processing image: {e}")

    print("-" * 20)

# Save results
df.to_csv("image_links_with_text.csv", index=False)
print("✅ Extracted text saved to image_links_with_text.csv")

# Display the DataFrame
display(df)

# %%
import pandas as pd
import joblib
import re

# Load CSV and model/vectorizer
df = pd.read_csv("image_links_with_text.csv")
model = joblib.load("sponsor_model.pkl")
vectorizer = joblib.load("tfidf_vectorizer.pkl")

# Clean text before transforming
df["clean_text"] = (
    df["extracted_text"]
    .fillna("")
    .str.lower()
    .apply(lambda x: re.sub(r'[^a-z\s]', '', x))
)

# Transform and predict
X = vectorizer.transform(df["clean_text"])
probs = model.predict_proba(X)[:, 1]

# Apply slightly relaxed threshold
df["is_sponsor"] = ["Yes" if p > 0.4 else "No" for p in probs]

# Save final results
df.to_csv("image_links_with_text_and_prediction.csv", index=False)
print("✅ Improved predictions saved to image_links_with_text_and_prediction.csv")

# %%
import pandas as pd
import datetime
import time
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import joblib
import re
from sklearn.feature_extraction.text import TfidfVectorizer

# ==============================================================
# 1️⃣ Load model and vectorizer
# ==============================================================
model = joblib.load("sponsor_model.pkl")
vectorizer = joblib.load("tfidf_vectorizer.pkl")

# ==============================================================
# 2️⃣ Brand keyword list
# ==============================================================
BRANDS = [
    "Apple", "Samsung", "Nike", "Adidas", "Sony",
    "Microsoft", "Toyota", "CocaCola", "Pepsi", "Amazon",
    "Google", "Tesla", "Intel", "Puma", "Oppo", "Vivo"
]

def extract_brand(text):
    for brand in BRANDS:
        if re.search(rf"\b{brand}\b", text, re.IGNORECASE):
            return brand
    return "Other"

# ==============================================================
# 3️⃣ Scrape image URLs + extract alt text
# ==============================================================
def scrape_images(url):
    try:
        response = requests.get(url, timeout=10)
        soup = BeautifulSoup(response.text, "html.parser")
        image_tags = soup.find_all("img")

        images = []
        for img in image_tags:
            src = img.get("src")
            alt_text = img.get("alt", "")
            if src:
                full_url = urljoin(url, src)
                images.append({"image_url": full_url, "alt_text": alt_text})
        return pd.DataFrame(images)
    except Exception as e:
        print(f"⚠️ Error scraping {url}: {e}")
        return pd.DataFrame(columns=["image_url", "alt_text"])

# ==============================================================
# 4️⃣ Predict sponsorship
# ==============================================================
def predict_sponsorship(texts):
    if not texts:
        return []
    X_new = vectorizer.transform(texts)
    return model.predict(X_new)

# ==============================================================
# 5️⃣ Load or create activity log
# ==============================================================
try:
    image_log = pd.read_csv("image_activity_log.csv")
except FileNotFoundError:
    image_log = pd.DataFrame(columns=[
        "brand", "image_url", "text", "is_sponsored",
        "url", "active_since", "active_until"
    ])

# ==============================================================
# 6️⃣ Main tracking function
# ==============================================================
def track_images(url):
    global image_log
    print(f"\n🔍 Checking images at: {url} — {datetime.datetime.now()}")

    # Step 1: Scrape images
    current_images = scrape_images(url)
    if current_images.empty:
        print("⚠️ No images found on the page.")
        return

    # Step 2: Clean text and predict
    current_images["clean_text"] = current_images["alt_text"].fillna("").str.lower()
    current_images["brand"] = current_images["clean_text"].apply(extract_brand)
    current_images["is_sponsored"] = predict_sponsorship(current_images["clean_text"].tolist())

    current_images["url"] = url

    # Step 3: Remove duplicates
    current_images.drop_duplicates(subset=["url", "image_url"], inplace=True)
    image_log.drop_duplicates(subset=["url", "image_url", "active_since"], inplace=True)

    # Step 4: Determine active/inactive sets
    existing_entries = image_log[image_log["url"] == url]
    active_old = set(existing_entries.loc[existing_entries["active_until"].isna(), "image_url"])
    new_set = set(current_images["image_url"])

    added = new_set - active_old
    removed = active_old - new_set

    # Step 5: Add new entries
    for img_url in added:
        row = current_images[current_images["image_url"] == img_url].iloc[0]
        entry = {
            "brand": row["brand"],
            "image_url": row["image_url"],
            "text": row["clean_text"],
            "is_sponsored": row["is_sponsored"],
            "url": url,
            "active_since": datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
            "active_until": None
        }
        image_log = pd.concat([image_log, pd.DataFrame([entry])], ignore_index=True)
        print(f"🆕 Added new image for {row['brand']}: {img_url}")

    # Step 6: Mark removed ones
    for img_url in removed:
        mask = (
            (image_log["url"] == url)
            & (image_log["image_url"] == img_url)
            & (image_log["active_until"].isna())
        )
        if mask.any():
            image_log.loc[mask, "active_until"] = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            print(f"❌ Marked removed image: {img_url}")

    # Step 7: Save clean CSV
    image_log.to_csv("image_activity_log.csv", index=False)
    print("✅ Image activity log updated and saved.")

# ==============================================================
# 7️⃣ Continuous monitoring loop
# ==============================================================
urls_to_track = ["https://iaryanyadav.github.io/project_1/"]

while True:
    for url in urls_to_track:
        track_images(url)

    print("⏳ Sleeping for 10 seconds before next check...\n")
    time.sleep(10)
